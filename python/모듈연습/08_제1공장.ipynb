# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/Colab Notebooks/모듈연습'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/모듈연습

# %%
import 참치모듈
import 공장설명

#공장설명.인사말출력()
#print('공장설립은 {}년도에 함'.format(공장설명.공장설립연도))

#참01호 = 참치모듈.참치선물세트(12,5,5)
#참01호.출력('참치선물세트01호')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-b26b53be1027> in <module>
# ----> 1 import 참치모듈
#       2 import 공장설명
#       3
#       4 #공장설명.인사말출력()
#       5 #print('공장설립은 {}년도에 함'.format(공장설명.공장설립연도))
#
# ModuleNotFoundError: No module named '참치모듈'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
